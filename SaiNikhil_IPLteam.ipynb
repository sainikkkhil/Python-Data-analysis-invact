# %% [markdown]
# # IPL Teams 1.1

# %% [markdown]
# ***Task 1: Import the pandas library and create a blank dataframe.***

# %%
import pandas as pd
data = pd.DataFrame()
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ***Task 2: Add a column named 'Teams' to the table with the below IPL team names, and then print the table.***

# %%
data["Teams"] = ["Mumbai Indians", "Chennai Super Kings", "Kolkata Knight Riders","Royal challengers Bangalore", "Rajasthan Royals"]
data
# Out:
#                          Teams
# 0               Mumbai Indians
# 1          Chennai Super Kings
# 2        Kolkata Knight Riders
# 3  Royal challengers Bangalore
# 4             Rajasthan Royals

# %% [markdown]
# ***Task 3: In the above table add one more column named "TotatMatches" played by the Teams.***

# %%
data["TotalMatches"]=[120, 90, 110, 100, 80]
data
# Out:
#                          Teams  TotalMatches
# 0               Mumbai Indians           120
# 1          Chennai Super Kings            90
# 2        Kolkata Knight Riders           110
# 3  Royal challengers Bangalore           100
# 4             Rajasthan Royals            80

# %% [markdown]
# # IPL Teams_1.2

# %% [markdown]
# ***Task 1: In the above table add a column named ‘MatchesWon’ to the table with the below ‘MatchesWon’ numbers against every team, and then print the table.***

# %%
data["MatchesWon"] = [80,70,60,40,50]
data
# Out:
#                          Teams  TotalMatches  MatchesWon
# 0               Mumbai Indians           120          80
# 1          Chennai Super Kings            90          70
# 2        Kolkata Knight Riders           110          60
# 3  Royal challengers Bangalore           100          40
# 4             Rajasthan Royals            80          50

# %% [markdown]
# ***Task 2: Add a column named ‘MatchesLost’ to the table. MatchesLost are calculated by the formula (TotalMatches-MatchesWon), and then print the table.***

# %%
data["MatchesLost"] = data["TotalMatches"] - data["MatchesWon"]
data
# Out:
#                          Teams  TotalMatches  MatchesWon  MatchesLost
# 0               Mumbai Indians           120          80           40
# 1          Chennai Super Kings            90          70           20
# 2        Kolkata Knight Riders           110          60           50
# 3  Royal challengers Bangalore           100          40           60
# 4             Rajasthan Royals            80          50           30

# %%
data["WinPercent"] = data["MatchesWon"] / data["TotalMatches"] * 100
data
# Out:
#                          Teams  TotalMatches  MatchesWon  MatchesLost  \
# 0               Mumbai Indians           120          80           40
# 1          Chennai Super Kings            90          70           20
# 2        Kolkata Knight Riders           110          60           50
# 3  Royal challengers Bangalore           100          40           60
# 4             Rajasthan Royals            80          50           30
#
#    WinPercent
# 0   66.666667
# 1   77.777778
# 2   54.545455
# 3   40.000000
# 4   62.500000

# %% [markdown]
# # IPL Teams_1.3

# %% [markdown]
# ***Task 1: Find the sum of total matches played by all the teams.***

# %%
data["TotalMatches"].sum()
# Out:
# 500

# %% [markdown]
# ***Task 2: Find the minimum number of matches played by any team.***

# %%
data["TotalMatches"].min()
# Out:
# 80

# %% [markdown]
# ***Task 3: Find the maximum number Of matches played by any team.***

# %%
data["TotalMatches"].max()
# Out:
# 120

# %% [markdown]
# ***Task 4: Find the total number of teams.***

# %%
data["Teams"].count()
# Out:
# 5

# %% [markdown]
# ***Task 5: Find the average of total matches won by all the teams.***

# %%
data["MatchesWon"].mean()
# Out:
# 60.0

# %% [markdown]
# ***Task 6: Find the average of total matches lost by all the teams.***

# %%
data["MatchesLost"].mean()
# Out:
# 40.0

# %% [markdown]
# ***Task 7: Find the maximum of 'WinPercent' by any team.***

# %%
data["WinPercent"].max()
# Out:
# 77.77777777777779
